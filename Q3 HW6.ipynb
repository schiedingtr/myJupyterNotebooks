# %% [markdown]
# # Question 3

# %%
import numpy as np
import math as m
a = np.array([1, -2, 16, 40, 0])
b = np.array([3.16, 25, -3, -6.5, 108])
print('c=', a - b)
d = m.sqrt((-2.16)**2 + (-27)**2 + 19**2 + 46.5**2 + 108**2)
print('length of c=', d)
from numpy.linalg import norm
print('Norm A=',norm(a, ord=2))
print('Norm B=',norm(b, ord=2))
B = norm(b, ord=2)
A = norm(a, ord=2)
print('A-B', A-B)
print('a * b', np.dot(a, b, out = None))
# Out:
# c= [  -2.16  -27.     19.     46.5  -108.  ]
# length of c= 122.1511997485084
# Norm A= 43.139309220245984
# Norm B= 111.13161386392262
# A-B -67.99230464367665
# a * b -354.84000000000003

# %%
print('cos of angle between two vectors', -354.84000000000003/(norm(a,ord=2)*norm(b,ord=2)))
# Out:
# cos of angle between two vectors -0.07401534413719323

# %%
print('angle between a and b', m.acos(-0.07401534413719323), 'radians')
# Out:
# angle between a and b 1.6448794174297847 radians
